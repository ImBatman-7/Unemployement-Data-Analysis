# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import plotly.express as px
import plotly.graph_objects as go

# %%
pth = "C:\\Users\\Manoj\\Desktop\\datasets\\Unemployment in India.xlsx"
df = pd.read_excel(pth)

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 754 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 41.4+ KB

# %%
df.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 749   False  False       False                             False
# 750   False  False       False                             False
# 751   False  False       False                             False
# 752   False  False       False                             False
# 753   False  False       False                             False
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0                  False                                     False  False
# ...

# %%
df.isnull().sum()
# Out:
# Region                                      14
#  Date                                       14
#  Frequency                                  14
#  Estimated Unemployment Rate (%)            14
#  Estimated Employed                         14
#  Estimated Labour Participation Rate (%)    14
# Area                                        14
# dtype: int64

# %%
specific_column = 'Region'

null_rows = df[df[specific_column].isnull()]
null_rows
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 359    NaN   NaN        NaN                               NaN
# 360    NaN   NaN        NaN                               NaN
# 361    NaN   NaN        NaN                               NaN
# 362    NaN   NaN        NaN                               NaN
# 363    NaN   NaN        NaN                               NaN
# 364    NaN   NaN        NaN                               NaN
# 365    NaN   NaN        NaN                               NaN
# 366    NaN   NaN        NaN                               NaN
# 367    NaN   NaN        NaN                               NaN
# 368    NaN   NaN        NaN                               NaN
# 369    NaN   NaN        NaN                               NaN
# 370    NaN   NaN        NaN                               NaN
# 371    NaN   NaN        NaN                               NaN
# 372    NaN   NaN        NaN                               NaN
#
# ...

# %%
df.dropna()
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
specific_column = 'Region'

null_rows = df[df[specific_column].isnull()]
null_rows
# Out:
#     Region  Date  Frequency   Estimated Unemployment Rate (%)  \
# 359    NaN   NaN        NaN                               NaN
# 360    NaN   NaN        NaN                               NaN
# 361    NaN   NaN        NaN                               NaN
# 362    NaN   NaN        NaN                               NaN
# 363    NaN   NaN        NaN                               NaN
# 364    NaN   NaN        NaN                               NaN
# 365    NaN   NaN        NaN                               NaN
# 366    NaN   NaN        NaN                               NaN
# 367    NaN   NaN        NaN                               NaN
# 368    NaN   NaN        NaN                               NaN
# 369    NaN   NaN        NaN                               NaN
# 370    NaN   NaN        NaN                               NaN
# 371    NaN   NaN        NaN                               NaN
# 372    NaN   NaN        NaN                               NaN
#
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %% [markdown]
# What is the employement rate in Maharashtra?

# %%
df.isnull()
# Out:
#      Region   Date   Frequency   Estimated Unemployment Rate (%)  \
# 0     False  False       False                             False
# 1     False  False       False                             False
# 2     False  False       False                             False
# 3     False  False       False                             False
# 4     False  False       False                             False
# ..      ...    ...         ...                               ...
# 749   False  False       False                             False
# 750   False  False       False                             False
# 751   False  False       False                             False
# 752   False  False       False                             False
# 753   False  False       False                             False
#
#       Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0                  False                                     False  False
# ...

# %%
df.dropna()
# Out:
#              Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1    Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2    Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3    Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4    Andhra Pradesh   30-09-2019    Monthly                              5.17
# ..              ...          ...        ...                               ...
# 749     West Bengal   29-02-2020    Monthly                              7.55
# 750     West Bengal   31-03-2020    Monthly                              6.67
# 751     West Bengal   30-04-2020    Monthly                             15.63
# 752     West Bengal   31-05-2020    Monthly                             15.22
# 753     West Bengal   30-06-2020    Monthly                              9.86
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 740 entries, 0 to 753
# Data columns (total 7 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Region                                    740 non-null    object
#  1    Date                                     740 non-null    object
#  2    Frequency                                740 non-null    object
#  3    Estimated Unemployment Rate (%)          740 non-null    float64
#  4    Estimated Employed                       740 non-null    float64
#  5    Estimated Labour Participation Rate (%)  740 non-null    float64
#  6   Area                                      740 non-null    object
# dtypes: float64(3), object(4)
# memory usage: 46.2+ KB

# %%
df_new = df[df["Region"].isnull()]
df_new
# Out:
# Empty DataFrame
# Columns: [Region,  Date,  Frequency,  Estimated Unemployment Rate (%),  Estimated Employed,  Estimated Labour Participation Rate (%), Area]
# Index: []

# %%
df.isnull().sum()
# Out:
# Region                                      0
#  Date                                       0
#  Frequency                                  0
#  Estimated Unemployment Rate (%)            0
#  Estimated Employed                         0
#  Estimated Labour Participation Rate (%)    0
# Area                                        0
# dtype: int64

# %% [markdown]
# What is unemployment rate in each Maharashtra?

# %%
#check states
df["Region"].unique()
# Out:
# array(['Andhra Pradesh', 'Assam', 'Bihar', 'Chhattisgarh', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Madhya Pradesh',
#        'Maharashtra', 'Meghalaya', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura',
#        'Uttar Pradesh', 'Uttarakhand', 'West Bengal', 'Chandigarh'],
#       dtype=object)

# %%
#check columns
df.columns
# Out:
# Index(['Region', ' Date', ' Frequency', ' Estimated Unemployment Rate (%)',
#        ' Estimated Employed', ' Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
#check MH
df_mh=df[df["Region"] == "Maharashtra"].iloc[:,3].mean()
df_mh.round(2)
# Out:
# 7.56

# %% [markdown]
# What are the Unemployement rate in Every Region?

# %%
df_all_region = df.groupby(df["Region"]).apply(lambda x : x.iloc[:,3].mean().round(2)).reset_index(name="EUR(%)")
df_all_region
# Out:
#               Region  EUR(%)
# 0     Andhra Pradesh    7.48
# 1              Assam    6.43
# 2              Bihar   18.92
# 3         Chandigarh   15.99
# 4       Chhattisgarh    9.24
# 5              Delhi   16.50
# 6                Goa    9.27
# 7            Gujarat    6.66
# 8            Haryana   26.28
# 9   Himachal Pradesh   18.54
# 10   Jammu & Kashmir   16.19
# 11         Jharkhand   20.58
# 12         Karnataka    6.68
# 13            Kerala   10.12
# 14    Madhya Pradesh    7.41
# 15       Maharashtra    7.56
# 16         Meghalaya    4.80
# 17            Odisha    5.66
# 18        Puducherry   10.22
# 19            Punjab   12.03
# 20         Rajasthan   14.06
# 21            Sikkim    7.25
# 22        Tamil Nadu    9.28
# 23         Telangana    7.74
# 24           Tripura   28.35
# 25     Uttar Pradesh   12.55
# 26       Uttarakhand    6.58
# 27       West Bengal    8.12

# %%
plt.figure(figsize=(16,12)) # whole region 16x12
sbn.set_theme(font_scale=1.3) #increase font by 30%
axx = sbn.barplot(data=df_all_region,x="EUR(%)",y='Region')
axx.bar_label(axx.containers[0],fmt='%.2f') #labels in the bar, .2f means 2 decimal points
plt.show()

# %% [markdown]
# Whether the unemployment rate have increased or decreased between the year 2019 to 2020?

# %%
df.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-05-2019    Monthly                              3.65
# 1  Andhra Pradesh   30-06-2019    Monthly                              3.05
# 2  Andhra Pradesh   31-07-2019    Monthly                              3.75
# 3  Andhra Pradesh   31-08-2019    Monthly                              3.32
# 4  Andhra Pradesh   30-09-2019    Monthly                              5.17
#
#     Estimated Employed   Estimated Labour Participation Rate (%)   Area
# 0           11999139.0                                     43.24  Rural
# 1           11755881.0                                     42.05  Rural
# 2           12086707.0                                     43.50  Rural
# 3           12285693.0                                     43.97  Rural
# 4           12256762.0                                     44.68  Rural

# %%
#removing spaces from columns
df.columns = [col.strip() for col in df.columns]
df.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Area'],
#       dtype='object')

# %%
#first we need to create a year column
# convert the date column into actual date format
# df.loc[0, 'Date'].year
df["Date"] = pd.to_datetime(df["Date"], errors="ignore")
# Out:
# C:\Users\Manoj\AppData\Local\Temp\ipykernel_6376\2714538075.py:4: UserWarning: Parsing dates in  %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df["Date"] = pd.to_datetime(df["Date"], errors="ignore")
# C:\Users\Manoj\AppData\Local\Temp\ipykernel_6376\2714538075.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Date"] = pd.to_datetime(df["Date"], errors="ignore")

# %%
df.loc[1, "Date"].year
# Out:
# 2019

# %%
df["Year"] = df.loc[:, "Date"].dt.year
# Out:
# C:\Users\Manoj\AppData\Local\Temp\ipykernel_6376\1483571590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Year"] = df.loc[:, "Date"].dt.year

# %%
df.head()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2019-05-31   Monthly                             3.65
# 1  Andhra Pradesh 2019-06-30   Monthly                             3.05
# 2  Andhra Pradesh 2019-07-31   Monthly                             3.75
# 3  Andhra Pradesh 2019-08-31   Monthly                             3.32
# 4  Andhra Pradesh 2019-09-30   Monthly                             5.17
#
#    Estimated Employed  Estimated Labour Participation Rate (%)   Area  Year
# 0          11999139.0                                    43.24  Rural  2019
# 1          11755881.0                                    42.05  Rural  2019
# 2          12086707.0                                    43.50  Rural  2019
# 3          12285693.0                                    43.97  Rural  2019
# 4          12256762.0                                    44.68  Rural  2019

# %%
df["Year"].unique()
# Out:
# array([2019, 2020])

# %%
# df[df["Year"] == 2019].iloc[:,3].mean().round(2)
year_ur = df.groupby(["Region", "Year"]).apply(lambda x:x.iloc[:,3].mean().round(2)).reset_index(name="Estimated Unemployment Rate in (%)")
year_ur.head(10)
# Out:
#            Region  Year  Estimated Unemployment Rate in (%)
# 0  Andhra Pradesh  2019                                4.83
# 1  Andhra Pradesh  2020                               11.01
# 2           Assam  2019                                6.42
# 3           Assam  2020                                6.44
# 4           Bihar  2019                               13.88
# 5           Bihar  2020                               25.63
# 6      Chandigarh  2019                               15.82
# 7      Chandigarh  2020                               16.33
# 8    Chhattisgarh  2019                                7.35
# 9    Chhattisgarh  2020                               11.76

# %%
# plt.figure(figsize=(25,24))
# fig_emp=px.bar(year_ur,x="Estimated Unemployment Rate in (%)",y='Region',color='Year',barmode='group')
# fig_emp.update_yaxes(tickmode='linear')
# fig_emp.show()

# %% [markdown]
# Which area(Rural or urban) have higher unemployment rate?

# %%
ru = df.groupby(df["Area"]).apply(lambda x : x.iloc[:,3].mean().round()).reset_index(name="EUR")
ru
# Out:
#     Area   EUR
# 0  Rural  10.0
# 1  Urban  13.0

# %%
empx=sbn.barplot(data=ru,y="EUR",x='Area')
sbn.set_theme(font_scale=1)
empx.bar_label(empx.containers[0])
plt.ylabel("Estimated Unemployment Rate in (%)",fontsize=12)
plt.show()

# %% [markdown]
# What are the labour participation rates in various states of the country?

# %%
df_lab = df.groupby(df["Region"]).apply(lambda x : x.iloc[:,5].mean().round(2)).reset_index(name="Lpp")
df_lab
# Out:
#               Region    Lpp
# 0     Andhra Pradesh  39.38
# 1              Assam  44.87
# 2              Bihar  38.15
# 3         Chandigarh  39.34
# 4       Chhattisgarh  42.81
# 5              Delhi  38.93
# 6                Goa  39.25
# 7            Gujarat  46.10
# 8            Haryana  42.74
# 9   Himachal Pradesh  44.22
# 10   Jammu & Kashmir  41.03
# 11         Jharkhand  41.67
# 12         Karnataka  41.35
# 13            Kerala  34.87
# 14    Madhya Pradesh  38.82
# 15       Maharashtra  42.30
# 16         Meghalaya  57.08
# 17            Odisha  38.93
# 18        Puducherry  38.99
# 19            Punjab  41.14
# 20         Rajasthan  39.97
# 21            Sikkim  46.07
# 22        Tamil Nadu  40.87
# 23         Telangana  53.00
# 24           Tripura  61.82
# 25     Uttar Pradesh  39.43
# 26       Uttarakhand  33.78
# 27       West Bengal  45.42

# %%
plt.figure(figsize=(16,12)) # whole region 16x12
sbn.set_theme(font_scale=1.3) #increase font by 30%
axx = sbn.barplot(data=df_lab,x="Lpp",y='Region')
axx.bar_label(axx.containers[0],fmt='%.2f') #labels in the bar, .2f means 2 decimal points
axx.set_xlabel("Labour Participation in %")
plt.show()

# %% [markdown]
# How many peoples were actually employed in year 2019 and 2020?

# %%
df_emp = df.groupby(df["Year"]).apply(lambda x : x.iloc[:,4].sum()).reset_index(name="ee")
df_emp
# Out:
#    Year            ee
# 0  2019  3.191880e+09
# 1  2020  2.139421e+09

# %%
plt.figure(figsize=(4,4)) # whole region 16x12
sbn.set_theme(font_scale=1.3) #increase font by 30%
axx = sbn.barplot(data=df_emp,x="Year",y='ee')
axx.set_ylabel("Estimated Employement")
plt.show()

# %% [markdown]
# Which Months in Year 2020 have the highest unemployment rate in the country?

# %%
df_11 = pd.read_csv("C:\\Users\\Manoj\\Desktop\\datasets\\Unemployment_Rate_upto_11_2020.csv")
df_11.head()
# Out:
#            Region         Date  Frequency   Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh   31-01-2020          M                              5.48
# 1  Andhra Pradesh   29-02-2020          M                              5.83
# 2  Andhra Pradesh   31-03-2020          M                              5.79
# 3  Andhra Pradesh   30-04-2020          M                             20.51
# 4  Andhra Pradesh   31-05-2020          M                             17.43
#
#     Estimated Employed   Estimated Labour Participation Rate (%) Region.1  \
# 0             16635535                                     41.02    South
# 1             16545652                                     40.90    South
# 2             15881197                                     39.18    South
# 3             11336911                                     33.10    South
# 4             12988845                                     36.46    South
#
#    longitude  latitude
# 0    15.9129     79.74
# ...

# %%
# df_11["Month"] = df_11["Date"].dt.month
df_11.columns = [col.strip() for col in df_11.columns]
df_11.isnull().sum()
# Out:
# Region                                     0
# Date                                       0
# Frequency                                  0
# Estimated Unemployment Rate (%)            0
# Estimated Employed                         0
# Estimated Labour Participation Rate (%)    0
# Region.1                                   0
# longitude                                  0
# latitude                                   0
# dtype: int64

# %%
df_11["Date"] = pd.to_datetime(df_11["Date"])
df_11.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 267 entries, 0 to 266
# Data columns (total 9 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Region                                   267 non-null    object
#  1   Date                                     267 non-null    datetime64[ns]
#  2   Frequency                                267 non-null    object
#  3   Estimated Unemployment Rate (%)          267 non-null    float64
#  4   Estimated Employed                       267 non-null    int64
#  5   Estimated Labour Participation Rate (%)  267 non-null    float64
#  6   Region.1                                 267 non-null    object
#  7   longitude                                267 non-null    float64
#  8   latitude                                 267 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1), object(3)
# memory usage: 18.9+ KB
# ...

# %%
import calendar

df_11["Month"] = df_11["Date"].dt.month
df_11["Month"] = df_11["Month"].apply(lambda x : calendar.month_abbr[x])
month_order = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct']
df_11['month_order'] = pd.Categorical(df_11['Month'], categories=month_order)
df_11.head()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2020-01-31         M                             5.48
# 1  Andhra Pradesh 2020-02-29         M                             5.83
# 2  Andhra Pradesh 2020-03-31         M                             5.79
# 3  Andhra Pradesh 2020-04-30         M                            20.51
# 4  Andhra Pradesh 2020-05-31         M                            17.43
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# 1            16545652                                    40.90    South
# 2            15881197                                    39.18    South
# 3            11336911                                    33.10    South
# 4            12988845                                    36.46    South
#
#    longitude  latitude Month month_order
# 0    15.9129     79.74   Jan         Jan
# ...

# %%
df_mon = df_11.groupby("month_order").apply(lambda x : x.iloc[:,3].mean().round(2)).reset_index(name="EUR%")
df_mon = df_mon.sort_values(by="month_order")
df_mon
# Out:
# C:\Users\Manoj\AppData\Local\Temp\ipykernel_6376\3554861698.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_mon = df_11.groupby("month_order").apply(lambda x : x.iloc[:,3].mean().round(2)).reset_index(name="EUR%")
#   month_order   EUR%
# 0         Jan   9.20
# 1         Feb   9.27
# 2         Mar  10.78
# 3         Apr  22.24
# 4         May  23.24
# 5         Jun  10.91
# 6         Jul   9.83
# 7         Aug  10.31
# 8         Sep   8.71
# 9         Oct   8.03

# %%
plt.figure(figsize=(8,6)) # whole region 16x12
sbn.set_theme(font_scale=1) #increase font by 30%
axx = sbn.barplot(data=df_mon,x="month_order",y='EUR%')
axx.bar_label(axx.containers[0],fmt='%.2f') #labels in the bar, .2f means 2 decimal points
axx.set_xlabel("Month")
plt.show()

# %% [markdown]
# What is Labour Participation rate and Unemployement rate in each month?

# %%
df_11_El = df_11.groupby("month_order")[["Estimated Unemployment Rate (%)","Estimated Labour Participation Rate (%)"]].mean().round(2)
df_11_El
# Out:
# C:\Users\Manoj\AppData\Local\Temp\ipykernel_6376\2921572460.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df_11_El = df_11.groupby("month_order")[["Estimated Unemployment Rate (%)","Estimated Labour Participation Rate (%)"]].mean().round(2)
#              Estimated Unemployment Rate (%)  \
# month_order
# Jan                                     9.20
# Feb                                     9.27
# Mar                                    10.78
# Apr                                    22.24
# May                                    23.24
# Jun                                    10.91
# Jul                                     9.83
# Aug                                    10.31
# Sep                                     8.71
# Oct                                     8.03
#
# ...

# %%
x1 = df_11["month_order"]
y1 = df_11_El["Estimated Unemployment Rate (%)"]
x2 = df_11["month_order"]
y2 = df_11_El["Estimated Labour Participation Rate (%)"]

fig = go.Figure()
fig.add_trace(go.Bar(x=x1,y=y1))
fig.add_trace(go.Bar(x=x2,y=y2))
fig.show()

# %% [markdown]
# Which regions in the country have the higher estimated employment?

# %%
df_11.head()
# Out:
#            Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0  Andhra Pradesh 2020-01-31         M                             5.48
# 1  Andhra Pradesh 2020-02-29         M                             5.83
# 2  Andhra Pradesh 2020-03-31         M                             5.79
# 3  Andhra Pradesh 2020-04-30         M                            20.51
# 4  Andhra Pradesh 2020-05-31         M                            17.43
#
#    Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# 0            16635535                                    41.02    South
# 1            16545652                                    40.90    South
# 2            15881197                                    39.18    South
# 3            11336911                                    33.10    South
# 4            12988845                                    36.46    South
#
#    longitude  latitude Month month_order
# 0    15.9129     79.74   Jan         Jan
# ...

# %%
df_11_r = df_11.groupby("Region.1").apply(lambda x : x.iloc[:,4].sum().round(1)).reset_index(name="ee")
df_11_r
# Out:
#     Region.1          ee
# 0       East   784094676
# 1      North  1032726546
# 2  Northeast   137450010
# 3      South   842435360
# 4       West   931175636

# %%
plt.figure(figsize=(6,5)) # whole region 16x12
sbn.set_theme(font_scale=0.8)
axx = sbn.barplot(data=df_11_r,x="Region.1",y='ee')
axx.bar_label(axx.containers[0],fmt='%.2f') #labels in the bar, .2f means 2 decimal points
axx.set_xlabel("Estimated Employement")
plt.show()

# %% [markdown]
# Which state in the country have the highest unemployment rate in year 2020?

# %%
df_11_st = df_11.groupby("Region").apply(lambda x : x.iloc[:,3].mean().round(2)).reset_index(name="eu")
df_11_st
# Out:
#               Region     eu
# 0     Andhra Pradesh   8.66
# 1              Assam   4.86
# 2              Bihar  19.47
# 3       Chhattisgarh   7.82
# 4              Delhi  18.41
# 5                Goa  12.17
# 6            Gujarat   6.38
# 7            Haryana  27.48
# 8   Himachal Pradesh  16.07
# 9    Jammu & Kashmir  16.48
# 10         Jharkhand  19.54
# 11         Karnataka   7.67
# 12            Kerala   9.43
# 13    Madhya Pradesh   6.85
# 14       Maharashtra   7.98
# 15         Meghalaya   3.87
# 16            Odisha   6.46
# 17        Puducherry  17.94
# 18            Punjab  11.98
# 19         Rajasthan  15.87
# 20            Sikkim   9.79
# 21        Tamil Nadu  12.19
# 22         Telangana   6.83
# 23           Tripura  25.06
# 24     Uttar Pradesh   9.74
# 25       Uttarakhand  11.16
# 26       West Bengal  10.19

# %%
plt.figure(figsize=(16,12)) # whole region 16x12
sbn.set_theme(font_scale=1.3) #increase font by 30%
axx = sbn.barplot(data=df_11_st,x="eu",y='Region')
axx.bar_label(axx.containers[0],fmt='%.2f') #labels in the bar, .2f means 2 decimal points
axx.set_xlabel("Estimated Unemployement in %")
plt.show()

# %% [markdown]
# Which state in the country have the highest employment Labor Participation rate in year 2020?

# %%
df_11_lab = df.groupby("Region").apply(lambda x : x.iloc[:,-5].mean().round(2)).reset_index(name="lab")
df_11_lab
# Out:
#               Region    lab
# 0     Andhra Pradesh   7.48
# 1              Assam   6.43
# 2              Bihar  18.92
# 3         Chandigarh  15.99
# 4       Chhattisgarh   9.24
# 5              Delhi  16.50
# 6                Goa   9.27
# 7            Gujarat   6.66
# 8            Haryana  26.28
# 9   Himachal Pradesh  18.54
# 10   Jammu & Kashmir  16.19
# 11         Jharkhand  20.58
# 12         Karnataka   6.68
# 13            Kerala  10.12
# 14    Madhya Pradesh   7.41
# 15       Maharashtra   7.56
# 16         Meghalaya   4.80
# 17            Odisha   5.66
# 18        Puducherry  10.22
# 19            Punjab  12.03
# 20         Rajasthan  14.06
# 21            Sikkim   7.25
# 22        Tamil Nadu   9.28
# 23         Telangana   7.74
# 24           Tripura  28.35
# 25     Uttar Pradesh  12.55
# 26       Uttarakhand   6.58
# 27       West Bengal   8.12

# %%
plt.figure(figsize=(16,12)) # whole region 16x12
sbn.set_theme(font_scale=1.3) #increase font by 30%
axx = sbn.barplot(data=df_11_lab,x="lab",y='Region')
axx.bar_label(axx.containers[0],fmt='%.2f') #labels in the bar, .2f means 2 decimal points
axx.set_xlabel("Labor Participation in %")
plt.show()

# %%
df_11.columns
# Out:
# Index(['Region', 'Date', 'Frequency', 'Estimated Unemployment Rate (%)',
#        'Estimated Employed', 'Estimated Labour Participation Rate (%)',
#        'Region.1', 'longitude', 'latitude', 'Month', 'month_order'],
#       dtype='object')

# %%
df_11
# Out:
#              Region       Date Frequency  Estimated Unemployment Rate (%)  \
# 0    Andhra Pradesh 2020-01-31         M                             5.48
# 1    Andhra Pradesh 2020-02-29         M                             5.83
# 2    Andhra Pradesh 2020-03-31         M                             5.79
# 3    Andhra Pradesh 2020-04-30         M                            20.51
# 4    Andhra Pradesh 2020-05-31         M                            17.43
# ..              ...        ...       ...                              ...
# 262     West Bengal 2020-06-30         M                             7.29
# 263     West Bengal 2020-07-31         M                             6.83
# 264     West Bengal 2020-08-31         M                            14.87
# 265     West Bengal 2020-09-30         M                             9.35
# 266     West Bengal 2020-10-31         M                             9.98
#
#      Estimated Employed  Estimated Labour Participation Rate (%) Region.1  \
# ...

# %% [markdown]
# #testing codes

# %%
df_test = df_11[df_11["Region.1"] == "South"] #returns df
n = df_test.groupby("Region").filter(lambda x : len(x) > 1) #returns df
n = n['Region'].unique() #n contains list
newdf = pd.DataFrame({"States" : n}) #df
newdf
# Out:
#            States
# 0  Andhra Pradesh
# 1       Karnataka
# 2          Kerala
# 3      Puducherry
# 4      Tamil Nadu
# 5       Telangana

# %%
n = df_test["Region"].value_counts()
x = n[n > 1].reset_index()
x["isD"] = x[["Region"]].duplicated("Region")
x
# Out:
#            Region  count    isD
# 0  Andhra Pradesh     10  False
# 1       Karnataka     10  False
# 2          Kerala     10  False
# 3      Puducherry     10  False
# 4      Tamil Nadu     10  False
# 5       Telangana     10  False

# %%
x.Region
# Out:
# 0    Andhra Pradesh
# 1         Karnataka
# 2            Kerala
# 3        Puducherry
# 4        Tamil Nadu
# 5         Telangana
# Name: Region, dtype: object

# %%
x1 = ["Joe", "Henry", "Sam", "Max"]
x2 = ["Joe", "Sam"]
ls = [x for x in x1 if x not in x2]
ls
# Out:
# ['Henry', 'Max']

# %%
x["datee"]=df_test["Date"]
# x["datee"] - x["datee"].shift(1)
x['date_diff'] = x["datee"] - x["datee"].shift(1)
ls = x[x['date_diff'] == "29 days" and ]
ls
# Out:
#       Region  count    isD      datee date_diff
# 1  Karnataka     10  False 2020-02-29   29 days
